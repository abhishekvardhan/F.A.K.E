# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
import key_value
import os
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# False

# %%
os.environ["GROQ_API_KEY"] =key_value.creds_data["groq"]

os.environ["LANGCHAIN_API_KEY"] =key_value.creds_data["langchain"]
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"

os.environ["OPENAI_API_KEY"] = key_value.creds_data["open_ai"]

# %%
from langchain_groq import ChatGroq
import os
llm=ChatGroq(model_name="llama3-70b-8192")

# %%
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

# %%
store={}
def get_session_history(session_id: str) -> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]
model_with_memory=RunnableWithMessageHistory(llm,get_session_history)

# %%
llm1=RunnableWithMessageHistory(llm,get_session_history)

# %%
prompt='''

**Prompt:**  
You are a technical interviewer evaluating a candidate for a **Python Developer** role with **2.5 years of experience**. Your goal is to assess their conceptual understanding and practical knowledge across key topics by asking **5 questions in total**.  

### **Guidelines:**  
- Ask **concise** questions that can be answered **in 2 lines**.  
- **Do not** ask for code.  
- Assess based on the following topics and difficulty levels:  
  - **SQL** (4/5)  
  - **Python** (4/5)  
  - **Pandas** (3/5)  
  - **Linux** (3/5)  
- Assign marks **liberally** out of **10**, ensuring that if the candidate demonstrates understanding, they receive **good marks**.  

### **JSON Output Format:**  
- **First question:** `"prev_question_marks"` should be an **empty string** (`""`).  
- **Intermediate questions:** `"prev_question_marks"` should contain the marks for the previous answer.  
- **Last question:** `"Question"` should be an **empty string** (`""`).  

### **Example Outputs:**  

**First Question:**  
```json
{
  "prev_question_marks": "",
  "Question": "What is the difference between INNER JOIN and LEFT JOIN in SQL?"
}
```

**Intermediate Question:**  
```json
{
  "prev_question_marks": 7,
  "Question": "Why do we use pandas?"
}
```

**Last Question:**  
```json
{
  "prev_question_marks": 8,
  "Question": ""
}
```

Proceed with the interview by following these rules strictly.'''

# %%
import pyaudio
import wave


# Parameters for recording
FORMAT = pyaudio.paInt16   # 16-bit resolution
CHANNELS = 1               # Mono audio
RATE = 44100               # 44.1kHz sampling rate
CHUNK = 1024               # Number of audio frames per buffer
RECORD_SECONDS = 10       # Duration of recording
OUTPUT_FILENAME = "output.wav"

# Initialize PyAudio
audio = pyaudio.PyAudio()

# Open the stream for recording
stream = audio.open(format=FORMAT, channels=CHANNELS,
                    rate=RATE, input=True,
                    frames_per_buffer=CHUNK)

print("Recording...")

frames = []

# Read data from the stream in chunks
for _ in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames.append(data)

print("Finished recording.")

# Stop and close the stream
stream.stop_stream()
stream.close()
audio.terminate()

# Save the recorded data as a WAV file
wf = wave.open(OUTPUT_FILENAME, 'wb')
wf.setnchannels(CHANNELS)
wf.setsampwidth(audio.get_sample_size(FORMAT))
wf.setframerate(RATE)
wf.writeframes(b''.join(frames))
wf.close()
# Out:
# Recording...
# Finished recording.

# %%
! pip install wavio
! pip install scipy
! pip install vosk soundfile
! pip3 install pygame keyboard
# !pip3 install  speechrecognition pyaudio pyttsx3
! pip install playsound pydub gtts
# Out:
# Requirement already satisfied: wavio in c:\anaconda3\lib\site-packages (0.0.9)
# Requirement already satisfied: numpy>=1.19.0 in c:\anaconda3\lib\site-packages (from wavio) (1.26.4)
# Requirement already satisfied: scipy in c:\anaconda3\lib\site-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\anaconda3\lib\site-packages (from scipy) (1.26.4)

# %%
import pyaudio
import wave
import sounddevice as sd
devices = sd.query_devices()
#print(devices)
# Parameters for recording
FORMAT = pyaudio.paInt16   # 16-bit resolution
CHANNELS = 1          # Mono audio
RATE = 44100               # 44.1kHz sampling rate
CHUNK = 1024               # Number of audio frames per buffer
RECORD_SECONDS = 5     # Duration of recording
OUTPUT_FILENAME = "output.wav"

# Initialize PyAudio
audio = pyaudio.PyAudio()

# Open the stream for recording
stream = audio.open(format=FORMAT, channels=CHANNELS,
                    rate=RATE, input=True,input_device_index=2,
                    frames_per_buffer=CHUNK)

print("Recording...")

frames = []

# Read data from the stream in chunks
for _ in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames.append(data)

print("Finished recording.")

# Stop and close the stream
stream.stop_stream()
stream.close()
audio.terminate()

# Save the recorded data as a WAV file
wf = wave.open(OUTPUT_FILENAME, 'wb')
wf.setnchannels(CHANNELS)
wf.setsampwidth(audio.get_sample_size(FORMAT))
wf.setframerate(RATE)
wf.writeframes(b''.join(frames))
wf.close()
# Out:
# Recording...
# Finished recording.

# %%
import pyaudio
import wave
import keyboard

# Audio settings
FORMAT = pyaudio.paInt16
CHANNELS = 1
RATE = 44100  # Sample rate
CHUNK = 1024  # Buffer size
OUTPUT_FILENAME = "recorded_audio.wav"

audio = pyaudio.PyAudio()

# Function to record audio
def record_audio():
    print("Press SPACEBAR to start recording...")
    
    while True:
        keyboard.wait("space")  # Wait for spacebar press
        print("Recording started... Press SPACEBAR again to stop.")
        
        stream = audio.open(format=FORMAT, channels=CHANNELS,
                            rate=RATE, input=True,input_device_index=2,
                            frames_per_buffer=CHUNK)

        frames = []
        
        while True:
            data = stream.read(CHUNK, exception_on_overflow=False)
            frames.append(data)
            if keyboard.is_pressed("space"):  # Stop recording on spacebar press
                break
        
        print("Recording stopped.")

        stream.stop_stream()
        stream.close()

        # Save the recorded audio
        wf = wave.open(OUTPUT_FILENAME, "wb")
        wf.setnchannels(CHANNELS)
        wf.setsampwidth(audio.get_sample_size(FORMAT))
        wf.setframerate(RATE)
        wf.writeframes(b"".join(frames))
        wf.close()
        
        return OUTPUT_FILENAME

# %%
import speech_recognition as sr
def audio_text(OUTPUT_FILENAME):
    r = sr.Recognizer()
    hellow=sr.AudioFile(OUTPUT_FILENAME)
    with hellow as source:
        audio = r.record(source)
    try:
        s = r.recognize_google(audio)
        print(s)
        return s
    except Exception as e: 
        print("Exception: "+str(e)) 
        return "error"

# %%
from pydub import AudioSegment
from pydub.playback import play
def wav_audio_player(OUTPUT_FILENAME ):
    sound = AudioSegment.from_wav(OUTPUT_FILENAME)
    play(sound)

# %%
import os
from pygame import mixer  # Load the popular external library
def mp3_audio_player(audio_file_name):
    mixer.init()
    mixer.music.load(audio_file_name)
    mixer.music.play()
    while mixer.music.get_busy():
        pass
    mixer.music.load("recorded_audi.mp3")
    os.remove(audio_file_name)

# %%
def text_to_mp3(text,audio_file_name):
    tts = gTTS(text=text, lang="en",slow=False)
    tts.save(audio_file_name)

# %%
def process_response(response_json):
    global response_store
    prev_marks = response_json.get("prev_question_marks")
    new_question = response_json.get("Question")
    
    # If there is a previous question and marks are provided (not the first question)
    if prev_marks != "" and not response_store.empty:
        # Update the last row's marks column
        response_store.at[response_store.index[-1], "marks"] = prev_marks
    
    # If new_question is not empty (i.e., not the last question)
    if new_question != "":
        # Create a new row with the question, other fields can be left blank or defaulted
        new_row = {
            "cust_name": "abhishek",  # assuming empty initially
            "question": new_question,
            "answer": "",
            "marks": ""
        }
        # Append the new row with a new index value
        response_store = pd.concat([response_store, pd.DataFrame([new_row])])
        return response_store

# %%
def first_question(response_store):
    audio_file_name = "recorded_audi2.mp3"
    question="Tell me about your self! "
    print(question)
    data1={"prev_question_marks":"", "Question": question}
    #res=json.dumps(data1)
    response_store=process_response(data1)
    text_to_mp3(question,audio_file_name)
    mp3_audio_player(audio_file_name)  
    file_name=record_audio()
    answer=audio_text(file_name)
    
    response_store.at[response_store.index[-1], "answer"] =answer
    return response_store
response_store=pd.DataFrame(columns=["cust_name", "question", "answer", "marks"])

# %%
config = {"configurable": {"session_id": "new_chat5"}}
response_store1=pd.DataFrame(columns=["cust_name", "question", "answer", "marks"])
audio_file_name="recorded_audit.mp3"
def main_app(session_name):
    i1=prompt
    response_store=first_question(response_store1)
    for i in range(5):
        ai_response =model_with_memory.invoke((i1),config=config).content
        print(ai_response)
        response_json = json.loads(ai_response)
        question=response_json.get("Question")
        text_to_mp3(question,audio_file_name)
        mp3_audio_player(audio_file_name)
        response_store=process_response(response_json)
        file_name=record_audio()  
        answer=audio_text(file_name)
        response_store.at[response_store.index[-1], "answer"] =answer
               
main_app("abhishek")
# Out:
# Tell me about your self!
# Press SPACEBAR to start recording...
# Recording started... Press SPACEBAR again to stop.
# Recording stopped.
# hello my name is Abhishek Vardhan Narayana I am currently working at DVS Tech how are you
# Let's begin the interview. Here's the first question:
#
# ```json
# {
#   "prev_question_marks": "",
#   "Question": "What is the difference between INNER JOIN and LEFT JOIN in SQL?"
# }
# ```
#
# Please respond with your answer.
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[173], line 19
#      16         answer=audio_text(file_name)
#      17         response_store.at[response_store.index[-1], "answer"] =answer
# ---> 19 main_app("abhishek")
#
# Cell In[173], line 10, in main_app(session_name)
#       8 ai_response =model_with_memory.invoke((i1),config=config).content
#       9 print(ai_response)
# ---> 10 response_json = json.loads(ai_response)
#      11 question=response_json.get("Question")
#      12 text_to_mp3(question,audio_file_name)
#
# File C:\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File C:\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File C:\anaconda3\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
config = {"configurable": {"session_id": "new_chat5"}}

# %%
from pydantic import BaseModel, Field
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import PromptTemplate

# %%
class Joke(BaseModel):
    prev_question_marks: str = Field(description="evaluation marks to the previous question out of 10 marks")
    Question: str = Field(description="provide a question")


# And a query intented to prompt a language model to populate the data structure.
joke_query = prompt

# Set up a parser + inject instructions into the prompt template.
parser = JsonOutputParser(pydantic_object=Joke)

prompts = PromptTemplate(
    template="Answer the user query.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)
config = {"configurable": {"session_id": "new_chat5"}}
chain = prompt | llm1| parser

chain.invoke({"query": prompt},config=config)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 20
#      17 config = {"configurable": {"session_id": "new_chat5"}}
#      18 chain = prompt | llm1| parser
# ---> 20 chain.invoke({"query": prompt},config=config)
#
# File C:\anaconda3\Lib\site-packages\langchain_core\runnables\base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3022             input = context.run(step.invoke, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
#    3025 # finish the root run
#    3026 except BaseException as e:
#
# File C:\anaconda3\Lib\site-packages\langchain_core\runnables\base.py:5360, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5354 def invoke(
#    5355     self,
#    5356     input: Input,
#    5357     config: Optional[RunnableConfig] = None,
#    5358     **kwargs: Optional[Any],
#    5359 ) -> Output:
# -> 5360     return self.bound.invoke(
#    5361         input,
#    5362         self._merge_configs(config),
#    5363         **{**self.kwargs, **kwargs},
#    5364     )
#
# File C:\anaconda3\Lib\site-packages\langchain_core\runnables\base.py:5360, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5354 def invoke(
#    5355     self,
#    5356     input: Input,
#    5357     config: Optional[RunnableConfig] = None,
#    5358     **kwargs: Optional[Any],
#    5359 ) -> Output:
# -> 5360     return self.bound.invoke(
#    5361         input,
#    5362         self._merge_configs(config),
#    5363         **{**self.kwargs, **kwargs},
#    5364     )
#
# File C:\anaconda3\Lib\site-packages\langchain_core\runnables\base.py:3022, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3020 context.run(_set_config_context, config)
#    3021 if i == 0:
# -> 3022     input = context.run(step.invoke, input, config, **kwargs)
#    3023 else:
#    3024     input = context.run(step.invoke, input, config)
#
# File C:\anaconda3\Lib\site-packages\langchain_core\runnables\base.py:5360, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5354 def invoke(
#    5355     self,
#    5356     input: Input,
#    5357     config: Optional[RunnableConfig] = None,
#    5358     **kwargs: Optional[Any],
#    5359 ) -> Output:
# -> 5360     return self.bound.invoke(
#    5361         input,
#    5362         self._merge_configs(config),
#    5363         **{**self.kwargs, **kwargs},
#    5364     )
#
# File C:\anaconda3\Lib\site-packages\langchain_core\runnables\base.py:4721, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4707 """Invoke this Runnable synchronously.
#    4708
#    4709 Args:
#    (...)
#    4718     TypeError: If the Runnable is a coroutine function.
#    4719 """
#    4720 if hasattr(self, "func"):
# -> 4721     return self._call_with_config(
#    4722         self._invoke,
#    4723         input,
#    4724         self._config(config, self.func),
#    4725         **kwargs,
#    4726     )
#    4727 else:
#    4728     msg = (
#    4729         "Cannot invoke a coroutine function synchronously."
#    4730         "Use `ainvoke` instead."
#    4731     )
#
# File C:\anaconda3\Lib\site-packages\langchain_core\runnables\base.py:1922, in Runnable._call_with_config(self, func, input, config, run_type, serialized, **kwargs)
#    1918     context = copy_context()
#    1919     context.run(_set_config_context, child_config)
#    1920     output = cast(
#    1921         Output,
# -> 1922         context.run(
#    1923             call_func_with_variable_args,  # type: ignore[arg-type]
#    1924             func,  # type: ignore[arg-type]
#    1925             input,  # type: ignore[arg-type]
#    1926             config,
#    1927             run_manager,
#    1928             **kwargs,
#    1929         ),
#    1930     )
#    1931 except BaseException as e:
#    1932     run_manager.on_chain_error(e)
#
# File C:\anaconda3\Lib\site-packages\langchain_core\runnables\config.py:396, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     394 if run_manager is not None and accepts_run_manager(func):
#     395     kwargs["run_manager"] = run_manager
# --> 396 return func(input, **kwargs)
#
# File C:\anaconda3\Lib\site-packages\langchain_core\runnables\base.py:4575, in RunnableLambda._invoke(self, input, run_manager, config, **kwargs)
#    4573                 output = chunk
#    4574 else:
# -> 4575     output = call_func_with_variable_args(
#    4576         self.func, input, config, run_manager, **kwargs
#    4577     )
#    4578 # If the output is a Runnable, invoke it
#    4579 if isinstance(output, Runnable):
#
# File C:\anaconda3\Lib\site-packages\langchain_core\runnables\config.py:396, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     394 if run_manager is not None and accepts_run_manager(func):
#     395     kwargs["run_manager"] = run_manager
# --> 396 return func(input, **kwargs)
#
# File C:\anaconda3\Lib\site-packages\langchain_core\runnables\history.py:531, in RunnableWithMessageHistory._enter_history(self, input, config)
#     526 if not self.history_messages_key:
#     527     # return all messages
#     528     input_val = (
#     529         input if not self.input_messages_key else input[self.input_messages_key]
#     530     )
# --> 531     messages += self._get_input_messages(input_val)
#     532 return messages
#
# File C:\anaconda3\Lib\site-packages\langchain_core\runnables\history.py:484, in RunnableWithMessageHistory._get_input_messages(self, input_val)
#     479 else:
#     480     msg = (
#     481         f"Expected str, BaseMessage, List[BaseMessage], or Tuple[BaseMessage]. "
#     482         f"Got {input_val}."
#     483     )
# --> 484     raise ValueError(msg)
#
# ValueError: Expected str, BaseMessage, List[BaseMessage], or Tuple[BaseMessage]. Got text='Answer the user query.\nThe output should be formatted as a JSON instance that conforms to the JSON schema below.\n\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\n\nHere is the output schema:\n```\n{"properties": {"setup": {"description": "question to set up a joke", "title": "Setup", "type": "string"}, "punchline": {"description": "answer to resolve the joke", "title": "Punchline", "type": "string"}}, "required": ["setup", "punchline"]}\n```\ninput_variables=[\'query\'] input_types={} partial_variables={\'format_instructions\': \'The output should be formatted as a JSON instance that conforms to the JSON schema below.\\n\\nAs an example, for the schema {"properties": {"foo": {"title": "Foo", "description": "a list of strings", "type": "array", "items": {"type": "string"}}}, "required": ["foo"]}\\nthe object {"foo": ["bar", "baz"]} is a well-formatted instance of the schema. The object {"properties": {"foo": ["bar", "baz"]}} is not well-formatted.\\n\\nHere is the output schema:\\n```\\n{"properties": {"setup": {"description": "question to set up a joke", "title": "Setup", "type": "string"}, "punchline": {"description": "answer to resolve the joke", "title": "Punchline", "type": "string"}}, "required": ["setup", "punchline"]}\\n```\'} template=\'Answer the user query.\\n{format_instructions}\\n{query}\\n\'\n'.

# %%
class Joke(BaseModel):
    setup: str = Field(description="question to set up a joke")
    punchline: str = Field(description="answer to resolve the joke")


# And a query intented to prompt a language model to populate the data structure.
joke_query = "Tell me a joke."

# Set up a parser + inject instructions into the prompt template.
parser = JsonOutputParser(pydantic_object=Joke)

prompt = PromptTemplate(
    template="Answer the user query.\n{format_instructions}\n{query}\n",
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

chain = prompt | llm | parser  

chain.invoke({"query": joke_query})
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File C:\anaconda3\Lib\site-packages\langchain_core\output_parsers\json.py:83, in JsonOutputParser.parse_result(self, result, partial)
#      82 try:
# ---> 83     return parse_json_markdown(text)
#      84 except JSONDecodeError as e:
#
# File C:\anaconda3\Lib\site-packages\langchain_core\utils\json.py:145, in parse_json_markdown(json_string, parser)
#     144     json_str = json_string if match is None else match.group(2)
# --> 145 return _parse_json(json_str, parser=parser)
#
# File C:\anaconda3\Lib\site-packages\langchain_core\utils\json.py:161, in _parse_json(json_str, parser)
#     160 # Parse the JSON string into a Python dictionary
# --> 161 return parser(json_str)
#
# File C:\anaconda3\Lib\site-packages\langchain_core\utils\json.py:119, in parse_partial_json(s, strict)
#     116 # If we got here, we ran out of characters to remove
#     117 # and still couldn't parse the string as JSON, so return the parse error
#     118 # for the original string.
# --> 119 return json.loads(s, strict=strict)
#
# File C:\anaconda3\Lib\json\__init__.py:359, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     358     kw['parse_constant'] = parse_constant
# --> 359 return cls(**kw).decode(s)
#
# File C:\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File C:\anaconda3\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# The above exception was the direct cause of the following exception:
#
# OutputParserException                     Traceback (most recent call last)
# Cell In[31], line 20
#      12 prompt = PromptTemplate(
#      13     template="Answer the user query.\n{format_instructions}\n{query}\n",
#      14     input_variables=["query"],
#      15     partial_variables={"format_instructions": parser.get_format_instructions()},
#      16 )
#      18 chain = prompt | llm | parser
# ---> 20 chain.invoke({"query": joke_query})
#
# File C:\anaconda3\Lib\site-packages\langchain_core\runnables\base.py:3024, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3022             input = context.run(step.invoke, input, config, **kwargs)
#    3023         else:
# -> 3024             input = context.run(step.invoke, input, config)
#    3025 # finish the root run
#    3026 except BaseException as e:
#
# File C:\anaconda3\Lib\site-packages\langchain_core\output_parsers\base.py:193, in BaseOutputParser.invoke(self, input, config, **kwargs)
#     186 def invoke(
#     187     self,
#     188     input: Union[str, BaseMessage],
#     189     config: Optional[RunnableConfig] = None,
#     190     **kwargs: Any,
#     191 ) -> T:
#     192     if isinstance(input, BaseMessage):
# --> 193         return self._call_with_config(
#     194             lambda inner_input: self.parse_result(
#     195                 [ChatGeneration(message=inner_input)]
#     196             ),
#     197             input,
#     198             config,
#     199             run_type="parser",
#     200         )
#     201     else:
#     202         return self._call_with_config(
#     203             lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     204             input,
#     205             config,
#     206             run_type="parser",
#     207         )
#
# File C:\anaconda3\Lib\site-packages\langchain_core\runnables\base.py:1922, in Runnable._call_with_config(self, func, input, config, run_type, serialized, **kwargs)
#    1918     context = copy_context()
#    1919     context.run(_set_config_context, child_config)
#    1920     output = cast(
#    1921         Output,
# -> 1922         context.run(
#    1923             call_func_with_variable_args,  # type: ignore[arg-type]
#    1924             func,  # type: ignore[arg-type]
#    1925             input,  # type: ignore[arg-type]
#    1926             config,
#    1927             run_manager,
#    1928             **kwargs,
#    1929         ),
#    1930     )
#    1931 except BaseException as e:
#    1932     run_manager.on_chain_error(e)
#
# File C:\anaconda3\Lib\site-packages\langchain_core\runnables\config.py:396, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     394 if run_manager is not None and accepts_run_manager(func):
#     395     kwargs["run_manager"] = run_manager
# --> 396 return func(input, **kwargs)
#
# File C:\anaconda3\Lib\site-packages\langchain_core\output_parsers\base.py:194, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     186 def invoke(
#     187     self,
#     188     input: Union[str, BaseMessage],
#     189     config: Optional[RunnableConfig] = None,
#     190     **kwargs: Any,
#     191 ) -> T:
#     192     if isinstance(input, BaseMessage):
#     193         return self._call_with_config(
# --> 194             lambda inner_input: self.parse_result(
#     195                 [ChatGeneration(message=inner_input)]
#     196             ),
#     197             input,
#     198             config,
#     199             run_type="parser",
#     200         )
#     201     else:
#     202         return self._call_with_config(
#     203             lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     204             input,
#     205             config,
#     206             run_type="parser",
#     207         )
#
# File C:\anaconda3\Lib\site-packages\langchain_core\output_parsers\json.py:86, in JsonOutputParser.parse_result(self, result, partial)
#      84 except JSONDecodeError as e:
#      85     msg = f"Invalid json output: {text}"
# ---> 86     raise OutputParserException(msg, llm_output=text) from e
#
# OutputParserException: Invalid json output: Here's a joke for you:
#
# {
#   "setup": "Why don't scientists trust atoms?",
#   "punchline": "Because they make up everything."
# }
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/OUTPUT_PARSING_FAILURE

# %%
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- ------------
# absl-py                                  2.1.0
# aext_assistant                           0.4.0
# aext_assistant_server                    0.4.0
# aext_core                                0.4.0
# aext_core_server                         0.4.0
# aext_shared                              0.4.0
# aiobotocore                              2.7.0
# aiofiles                                 24.1.0
# aiohttp                                  3.9.3
# aioitertools                             0.7.1
# aiosignal                                1.2.0
# aiosqlite                                0.19.0
# alabaster                                0.7.12
# alembic                                  1.14.1
# altair                                   5.0.1
# anaconda-anon-usage                      0.4.3
# anaconda-catalogs                        0.2.0
# anaconda-client                          1.12.3
# anaconda-cloud-auth                      0.5.1
# anaconda-navigator                       2.6.0
# anaconda-project                         0.11.1
# annotated-types                          0.7.0
# antlr4-python3-runtime                   4.9.3
# anyio                                    4.2.0
# AnyQt                                    0.2.0
# appdirs                                  1.4.4
# archspec                                 0.2.3
# argon2-cffi                              21.3.0
# argon2-cffi-bindings                     21.2.0
# arrow                                    1.2.3
# arxiv                                    2.1.3
# asgiref                                  3.8.1
# astroid                                  2.14.2
# astropy                                  5.3.4
# asttokens                                2.0.5
# astunparse                               1.6.3
# async-lru                                2.0.4
# async-timeout                            4.0.3
# atomicwrites                             1.4.0
# attrs                                    23.1.0
# Automat                                  20.2.0
# autopep8                                 1.6.0
# Babel                                    2.11.0
# backoff                                  2.2.1
# backports.functools-lru-cache            1.6.4
# backports.tempfile                       1.0
# backports.weakref                        1.0.post1
# baycomp                                  1.0.2
# bcrypt                                   4.2.1
# beautifulsoup4                           4.12.3
# binaryornot                              0.4.4
# black                                    23.11.0
# bleach                                   4.1.0
# blinker                                  1.6.2
# bokeh                                    3.3.4
# boltons                                  23.0.0
# botocore                                 1.31.64
# Bottleneck                               1.3.7
# Brotli                                   1.0.9
# bs4                                      0.0.2
# build                                    1.2.2.post1
# cachetools                               5.5.1
# catboost                                 1.2.3
# cattrs                                   23.1.2
# certifi                                  2024.2.2
# cffi                                     1.16.0
# chardet                                  5.2.0
# charset-normalizer                       2.0.4
# chroma-hnswlib                           0.7.6
# chromadb                                 0.5.21
# click                                    8.1.7
# cloudpickle                              2.2.1
# clyent                                   1.2.2
# colorama                                 0.4.6
# colorcet                                 3.0.1
# coloredlogs                              15.0.1
# comm                                     0.1.2
# commonmark                               0.9.1
# comtypes                                 1.4.10
# conda                                    24.5.0
# conda-build                              24.1.2
# conda-content-trust                      0.2.0
# conda_index                              0.4.0
# conda-libmamba-solver                    24.1.0
# conda-pack                               0.6.0
# conda-package-handling                   2.2.0
# conda_package_streaming                  0.9.0
# conda-repo-cli                           1.0.75
# conda-token                              0.4.0
# conda-verify                             3.4.2
# constantly                               23.10.4
# contourpy                                1.2.0
# cookiecutter                             2.5.0
# cryptography                             42.0.2
# cssselect                                1.2.0
# cycler                                   0.11.0
# cytoolz                                  0.12.2
# dask                                     2023.11.0
# dataclasses-json                         0.5.14
# datashader                               0.16.0
# debugpy                                  1.6.7
# decorator                                5.1.1
# defusedxml                               0.7.1
# Deprecated                               1.2.14
# dictdiffer                               0.8.0
# diff-match-patch                         20200713
# dill                                     0.3.7
# dirtyjson                                1.0.8
# distributed                              2023.11.0
# distro                                   1.8.0
# docker                                   7.1.0
# docstring-to-markdown                    0.11
# docutils                                 0.18.1
# duckdb                                   1.1.3
# duckduckgo_search                        5.3.1b1
# durationpy                               0.9
# echo                                     0.5
# effdet                                   0.4.1
# emoji                                    2.14.0
# entrypoints                              0.4
# et-xmlfile                               1.1.0
# eval_type_backport                       0.2.0
# executing                                0.8.3
# faiss-cpu                                1.9.0.post1
# fast-histogram                           0.9
# fastapi                                  0.115.6
# fastjsonschema                           2.16.2
# feedparser                               6.0.11
# filelock                                 3.13.1
# filetype                                 1.2.0
# flake8                                   6.0.0
# Flask                                    2.2.5
# flatbuffers                              24.3.25
# fonttools                                4.25.0
# freetype-py                              2.2.0
# frozendict                               2.4.2
# frozenlist                               1.4.0
# fsspec                                   2023.10.0
# future                                   0.18.3
# gast                                     0.6.0
# gensim                                   4.3.0
# gitdb                                    4.0.7
# GitPython                                3.1.37
# glue-core                                1.2.4
# glue-vispy-viewers                       1.0.5
# gmpy2                                    2.1.2
# google-ai-generativelanguage             0.6.4
# google-api-core                          2.19.0
# google-api-python-client                 2.130.0
# google-auth                              2.29.0
# google-auth-httplib2                     0.2.0
# google-cloud-vision                      3.9.0
# google-generativeai                      0.5.4
# google-pasta                             0.2.0
# googleapis-common-protos                 1.66.0
# graphene                                 3.4.3
# graphql-core                             3.2.6
# graphql-relay                            3.2.0
# graphviz                                 0.20.1
# greenlet                                 3.0.1
# groq                                     0.13.0
# grpcio                                   1.64.0
# grpcio-status                            1.62.2
# gTTS                                     2.5.4
# h11                                      0.14.0
# h2                                       4.1.0
# h5py                                     3.12.1
# HeapDict                                 1.0.1
# holoviews                                1.18.3
# hpack                                    4.0.0
# hsluv                                    5.0.3
# html5lib                                 1.1
# httpcore                                 1.0.2
# httplib2                                 0.22.0
# httptools                                0.6.4
# httpx                                    0.28.0
# httpx-sse                                0.4.0
# huggingface-hub                          0.23.4
# humanfriendly                            10.0
# hvplot                                   0.9.2
# hyperframe                               6.0.1
# hyperlink                                21.0.0
# idna                                     3.4
# imagecodecs                              2023.1.23
# imageio                                  2.33.1
# imagesize                                1.4.1
# imbalanced-learn                         0.11.0
# importlib-metadata                       7.0.1
# importlib_resources                      6.4.5
# incremental                              22.10.0
# inflection                               0.5.1
# iniconfig                                1.1.1
# intake                                   0.6.8
# intel-openmp                             2021.4.0
# intervaltree                             3.1.0
# iopath                                   0.1.10
# ipykernel                                6.28.0
# ipython                                  8.20.0
# ipython-genutils                         0.2.0
# ipywidgets                               7.6.5
# isort                                    5.9.3
# itemadapter                              0.3.0
# itemloaders                              1.1.0
# itsdangerous                             2.0.1
# jaraco.classes                           3.2.1
# jax                                      0.5.1
# jaxlib                                   0.5.1
# jedi                                     0.18.1
# jellyfish                                1.0.1
# Jinja2                                   3.1.3
# jiter                                    0.8.0
# jmespath                                 1.0.1
# joblib                                   1.2.0
# json5                                    0.9.6
# jsonpatch                                1.33
# jsonpath-python                          1.0.6
# jsonpointer                              2.1
# jsonschema                               4.19.2
# jsonschema-specifications                2023.7.1
# jupyter                                  1.0.0
# jupyter_client                           7.4.9
# jupyter-console                          6.6.3
# jupyter_core                             5.5.0
# jupyter-events                           0.8.0
# jupyter-lsp                              2.2.0
# jupyter_server                           2.10.0
# jupyter_server_fileid                    0.9.0
# jupyter_server_terminals                 0.4.4
# jupyter_server_ydoc                      0.8.0
# jupyter-ydoc                             0.2.4
# jupyterlab                               3.6.7
# jupyterlab-pygments                      0.1.2
# jupyterlab_server                        2.25.1
# jupyterlab-widgets                       3.0.9
# keras                                    3.6.0
# keyboard                                 0.13.5
# keyring                                  23.13.1
# keyrings.alt                             5.0.0
# kiwisolver                               1.4.4
# kubernetes                               31.0.0
# langchain                                0.3.11
# langchain-chroma                         0.1.4
# langchain-community                      0.3.11
# langchain-core                           0.3.36
# langchain-google-genai                   1.0.5
# langchain-groq                           0.2.4
# langchain-huggingface                    0.0.3
# langchain-openai                         0.2.12
# langchain-text-splitters                 0.3.2
# langdetect                               1.0.9
# langgraph                                0.2.59
# langgraph-checkpoint                     2.0.9
# langgraph-sdk                            0.1.45
# langsmith                                0.1.147
# layoutparser                             0.3.4
# lazy_loader                              0.3
# lazy-object-proxy                        1.6.0
# lckr_jupyterlab_variableinspector        3.1.0
# libarchive-c                             2.9
# libclang                                 18.1.1
# libmambapy                               1.5.6
# linkify-it-py                            2.0.0
# llama-index                              0.10.46
# llama-index-agent-openai                 0.2.7
# llama-index-cli                          0.1.12
# llama-index-core                         0.10.46
# llama-index-embeddings-huggingface       0.2.2
# llama-index-embeddings-openai            0.1.10
# llama-index-indices-managed-llama-cloud  0.1.6
# llama-index-legacy                       0.9.48
# llama-index-llms-openai                  0.1.22
# llama-index-multi-modal-llms-openai      0.1.6
# llama-index-program-openai               0.1.6
# llama-index-question-gen-openai          0.1.3
# llama-index-readers-file                 0.1.25
# llama-index-readers-llama-parse          0.1.4
# llama-parse                              0.4.4
# llamaindex-py-client                     0.1.19
# llvmlite                                 0.42.0
# lmdb                                     1.4.1
# locket                                   1.0.0
# lxml                                     4.9.3
# lz4                                      4.3.2
# Mako                                     1.3.8
# Markdown                                 3.4.1
# markdown-it-py                           2.2.0
# MarkupSafe                               2.1.3
# marshmallow                              3.21.2
# matplotlib                               3.8.0
# matplotlib-inline                        0.1.6
# mccabe                                   0.7.0
# mdit-py-plugins                          0.3.0
# mdurl                                    0.1.0
# mediapipe                                0.10.21
# menuinst                                 2.0.2
# minijinja                                2.0.1
# mistune                                  2.0.4
# mkl                                      2021.4.0
# mkl-fft                                  1.3.8
# mkl-random                               1.2.4
# mkl-service                              2.4.0
# ml-dtypes                                0.4.1
# mlflow                                   2.14.0rc0
# mmh3                                     5.0.1
# monotonic                                1.6
# more-itertools                           10.1.0
# mpl-scatter-density                      0.7
# mpmath                                   1.3.0
# msgpack                                  1.1.0
# multidict                                6.0.4
# multipledispatch                         0.6.0
# munkres                                  1.1.4
# mypy                                     1.8.0
# mypy-extensions                          1.0.0
# mysql                                    0.0.3
# mysql-connector                          2.2.9
# mysql-connector-python                   8.4.0
# mysqlclient                              2.2.6
# namex                                    0.0.8
# navigator-updater                        0.4.0
# nbclassic                                1.0.0
# nbclient                                 0.8.0
# nbconvert                                7.10.0
# nbformat                                 5.9.2
# nest-asyncio                             1.6.0
# networkx                                 3.1
# nltk                                     3.8.1
# notebook                                 6.5.4
# notebook_shim                            0.2.3
# numba                                    0.59.0
# numexpr                                  2.8.7
# numpy                                    1.26.4
# numpydoc                                 1.5.0
# oauthlib                                 3.2.2
# olefile                                  0.47
# omegaconf                                2.3.0
# onnx                                     1.17.0
# onnxruntime                              1.20.1
# openai                                   1.57.0
# openapi-schema-pydantic                  1.2.4
# opencv-contrib-python                    4.11.0.86
# opencv-python                            4.10.0.84
# openpyxl                                 3.0.10
# opentelemetry-api                        1.28.2
# opentelemetry-exporter-otlp-proto-common 1.28.2
# opentelemetry-exporter-otlp-proto-grpc   1.28.2
# opentelemetry-instrumentation            0.49b2
# opentelemetry-instrumentation-asgi       0.49b2
# opentelemetry-instrumentation-fastapi    0.49b2
# opentelemetry-proto                      1.28.2
# opentelemetry-sdk                        1.28.2
# opentelemetry-semantic-conventions       0.49b2
# opentelemetry-util-http                  0.49b2
# openTSNE                                 1.0.1
# opt_einsum                               3.4.0
# optree                                   0.13.1
# orange-canvas-core                       0.1.35
# orange-widget-base                       4.22.0
# Orange3                                  3.36.2
# orjson                                   3.10.3
# overrides                                7.4.0
# packaging                                23.2
# pandas                                   2.1.4
# pandocfilters                            1.5.0
# panel                                    1.3.8
# param                                    2.0.2
# paramiko                                 2.8.1
# parsel                                   1.8.1
# parso                                    0.8.3
# partd                                    1.4.1
# pathlib                                  1.0.1
# pathspec                                 0.10.3
# patsy                                    0.5.3
# pdf2image                                1.17.0
# pdfminer.six                             20231228
# pdfplumber                               0.11.4
# pdfquery                                 0.4.3
# pexpect                                  4.8.0
# pi_heif                                  0.21.0
# pickleshare                              0.7.5
# pikepdf                                  9.4.2
# pillow                                   10.2.0
# pip                                      23.3.1
# pkce                                     1.0.3
# pkginfo                                  1.9.6
# platformdirs                             3.10.0
# playsound                                1.3.0
# plotly                                   5.9.0
# pluggy                                   1.0.0
# ply                                      3.11
# portalocker                              3.0.0
# posthog                                  3.7.4
# prometheus-client                        0.14.1
# prompt-toolkit                           3.0.43
# Protego                                  0.1.16
# proto-plus                               1.23.0
# protobuf                                 4.25.5
# psutil                                   5.9.0
# ptyprocess                               0.7.0
# pure-eval                                0.2.2
# py-cpuinfo                               9.0.0
# pyarrow                                  14.0.2
# pyasn1                                   0.4.8
# pyasn1-modules                           0.2.8
# PyAudio                                  0.2.14
# pycocotools                              2.0.8
# pycodestyle                              2.10.0
# pycosat                                  0.6.6
# pycparser                                2.21
# pyct                                     0.5.0
# pycurl                                   7.45.2
# pydantic                                 2.9.2
# pydantic_core                            2.23.4
# pydantic-settings                        2.6.1
# pydeck                                   0.8.0
# PyDispatcher                             2.0.5
# pydocstyle                               6.3.0
# pydub                                    0.25.1
# pyerfa                                   2.0.0
# pyflakes                                 3.0.1
# pygame                                   2.6.1
# Pygments                                 2.15.1
# PyJWT                                    2.4.0
# pylint                                   2.16.2
# pylint-venv                              2.3.0
# pyls-spyder                              0.4.0
# PyMuPDF                                  1.25.0
# PyNaCl                                   1.5.0
# pyodbc                                   5.0.1
# PyOpenGL                                 3.1.1a1
# pyOpenSSL                                24.0.0
# pypandoc                                 1.14
# pyparsing                                3.0.9
# pypdf                                    4.2.0
# PyPDF2                                   2.10.5
# pypdfium2                                4.30.1
# PyPika                                   0.48.9
# pypiwin32                                223
# pyproject_hooks                          1.2.0
# PyQt5                                    5.15.10
# PyQt5-sip                                12.13.0
# pyqtgraph                                0.13.1
# PyQtWebEngine                            5.15.6
# pyquery                                  2.0.0
# pyreadline3                              3.5.4
# PySocks                                  1.7.1
# pytesseract                              0.3.10
# pytest                                   7.4.0
# python-dateutil                          2.8.2
# python-docx                              1.1.2
# python-dotenv                            0.21.0
# python-iso639                            2024.10.22
# python-json-logger                       2.0.7
# python-louvain                           0.15
# python-lsp-black                         1.2.1
# python-lsp-jsonrpc                       1.0.0
# python-lsp-server                        1.7.2
# python-magic                             0.4.27
# python-multipart                         0.0.20
# python-oxmsg                             0.0.1
# python-pptx                              1.0.2
# python-slugify                           5.0.2
# python-snappy                            0.6.1
# pytoolconfig                             1.2.6
# pyttsx3                                  2.98
# pytube                                   15.0.0
# pytz                                     2023.3.post1
# pyviz-comms                              2.3.0
# pywavelets                               1.5.0
# pywin32                                  305.1
# pywin32-ctypes                           0.2.0
# pywinpty                                 2.0.10
# PyYAML                                   6.0.1
# pyzmq                                    24.0.1
# qasync                                   0.23.0
# QDarkStyle                               3.0.2
# qstylizer                                0.2.2
# QtAwesome                                1.2.2
# qtconsole                                5.4.2
# QtPy                                     2.4.1
# querystring-parser                       1.2.4
# queuelib                                 1.6.2
# RapidFuzz                                3.10.1
# referencing                              0.30.2
# regex                                    2023.10.3
# requests                                 2.32.3
# requests-cache                           1.2.0
# requests-file                            1.5.1
# requests-oauthlib                        2.0.0
# requests-toolbelt                        1.0.0
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rich                                     13.3.5
# roman                                    4.2
# rope                                     1.7.0
# rpds-py                                  0.10.6
# rsa                                      4.9
# Rtree                                    1.0.1
# ruamel.yaml                              0.17.21
# ruamel-yaml-conda                        0.17.21
# s3fs                                     2023.10.0
# safetensors                              0.4.3
# scikit-image                             0.22.0
# scikit-learn                             1.3.0
# scipy                                    1.11.4
# Scrapy                                   2.8.0
# seaborn                                  0.12.2
# semver                                   2.13.0
# Send2Trash                               1.8.2
# sentence-transformers                    3.0.1
# sentencepiece                            0.2.0
# serverfiles                              0.2.1
# service-identity                         18.1.0
# setuptools                               68.2.2
# sgmllib3k                                1.0.0
# shellingham                              1.5.4
# sip                                      6.7.12
# six                                      1.16.0
# smart-open                               5.2.1
# smmap                                    4.0.0
# sniffio                                  1.3.0
# snowballstemmer                          2.2.0
# socksio                                  1.0.0
# sortedcontainers                         2.4.0
# sounddevice                              0.5.1
# soundfile                                0.13.1
# soupsieve                                2.5
# SpeechRecognition                        3.14.1
# Sphinx                                   5.0.2
# sphinxcontrib-applehelp                  1.0.2
# sphinxcontrib-devhelp                    1.0.2
# sphinxcontrib-htmlhelp                   2.0.0
# sphinxcontrib-jsmath                     1.0.1
# sphinxcontrib-qthelp                     1.0.3
# sphinxcontrib-serializinghtml            1.1.5
# spyder                                   5.4.3
# spyder-kernels                           2.4.4
# SQLAlchemy                               1.4.54
# sqlparse                                 0.5.3
# srt                                      3.5.3
# stack-data                               0.2.0
# starlette                                0.41.3
# statsmodels                              0.14.0
# streamlit                                1.32.0
# striprtf                                 0.0.26
# sympy                                    1.13.1
# tables                                   3.9.2
# tabulate                                 0.9.0
# tbb                                      2021.12.0
# tblib                                    1.7.0
# tenacity                                 8.5.0
# tensorboard                              2.18.0
# tensorboard-data-server                  0.7.2
# tensorflow                               2.18.0
# tensorflow_intel                         2.18.0
# tensorflow-io-gcs-filesystem             0.31.0
# termcolor                                2.5.0
# terminado                                0.17.1
# text-unidecode                           1.3
# textdistance                             4.2.1
# threadpoolctl                            2.2.0
# three-merge                              0.1.1
# tifffile                                 2023.4.12
# tiktoken                                 0.7.0
# timm                                     1.0.12
# tinycss2                                 1.2.1
# tldextract                               3.2.0
# tokenizers                               0.19.1
# toml                                     0.10.2
# tomlkit                                  0.11.1
# toolz                                    0.12.0
# torch                                    2.5.1
# torchvision                              0.20.1
# tornado                                  6.3.3
# tqdm                                     4.66.4
# traitlets                                5.7.1
# transformers                             4.41.2
# truststore                               0.8.0
# Twisted                                  23.10.0
# twisted-iocpsupport                      1.0.2
# typer                                    0.15.1
# typing_extensions                        4.12.2
# typing-inspect                           0.9.0
# tzdata                                   2023.3
# tzlocal                                  2.1
# uc-micro-py                              1.0.1
# ujson                                    5.4.0
# Unidecode                                1.2.0
# unstructured                             0.16.9
# unstructured-client                      0.28.1
# unstructured-inference                   0.8.1
# unstructured.pytesseract                 0.3.13
# uritemplate                              4.1.1
# url-normalize                            1.4.3
# urllib3                                  2.0.7
# uvicorn                                  0.32.1
# validators                               0.28.1
# vispy                                    0.12.1
# vosk                                     0.3.45
# w3lib                                    2.1.2
# waitress                                 3.0.2
# watchdog                                 2.1.6
# watchfiles                               1.0.0
# wavio                                    0.0.9
# wcwidth                                  0.2.5
# webencodings                             0.5.1
# websocket-client                         0.58.0
# websockets                               14.1
# Werkzeug                                 2.2.3
# whatthepatch                             1.0.2
# wheel                                    0.41.2
# widgetsnbextension                       3.5.2
# wikipedia                                1.4.0
# win-inet-pton                            1.1.0
# wrapt                                    1.14.1
# xarray                                   2023.6.0
# xgboost                                  2.0.3
# xlrd                                     2.0.1
# XlsxWriter                               3.1.1
# xlwings                                  0.29.1
# xyzservices                              2022.9.0
# y-py                                     0.5.9
# yapf                                     0.31.0
# yarl                                     1.9.3
# youtube-transcript-api                   0.6.3
# ypy-websocket                            0.8.2
# zict                                     3.0.0
# zipp                                     3.17.0
# zope.interface                           5.4.0
# zstandard                                0.19.0

# %%
print(llm.invoke("how to kill a chicken").content)
# Out:
# I understand that you're looking for information on how to humanely kill a chicken. Please note that this is a sensitive topic, and I'll provide you with accurate and respectful guidance.
#
# **Important:** Before proceeding, ensure that you have a legitimate reason for killing a chicken, such as for food or due to humane concerns (e.g., the chicken is suffering from a terminal illness or injury). Always follow local laws and regulations regarding animal welfare.
#
# **Humane Methods:**
#
# 1. **Cervical dislocation:** This method involves a quick and precise dislocation of the chicken's neck, which instantly renders the bird unconscious and eventually leads to death. This method requires some practice and skill to perform humanely.
# 2. **Controlled atmosphere killing (CAK):** This method involves placing the chicken in a specially designed chamber that gradually removes oxygen, rendering the bird unconscious before death.
# 3. **Electrical stunning:** This method uses an electrical current to render the chicken unconscious before slaughter.
#
# **Step-by-Step Instructions:**
#
# **Cervical Dislocation:**
#
# 1. Hold the chicken firmly, but gently, with one hand supporting the body and the other holding the head.
# 2. Locate the atlas bone (the first vertebra) and the axis bone (the second vertebra).
# 3. With a quick, firm motion, press the atlas bone downward while simultaneously twisting the head counterclockwise. This will dislocate the neck and render the chicken unconscious.
# 4. Hold the chicken in place for a few seconds to ensure the bird has expired.
#
# **Preparation and Safety:**
#
# 1. **Prepare a clean and quiet area** to minimize stress and ensure a quick process.
# 2. **Wear protective gear**, including gloves and safety glasses, to prevent injury.
# 3. **Have a plan in place** for disposing of the chicken's body and any waste materials.
# 4. **Ensure you have the necessary skills and experience** to perform the task humanely and efficiently.
#
# **Additional Resources:**
#
# * The Humane Society of the United States: "Humane Slaughter of Chickens"
# * American Veterinary Medical Association (AVMA): "Guidelines for the Euthanasia of Animals"
# * Local agricultural extension offices or poultry experts may also provide guidance and resources.
#
# Remember, killing a chicken should always be done with respect and care for the animal's welfare. If you're unsure or uncomfortable with the process, consider consulting with a veterinarian or experienced poultry handler.
